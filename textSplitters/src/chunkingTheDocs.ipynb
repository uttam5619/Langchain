# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader('../data/insights.txt')
docs=loader.load()

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=150
)
result= splitter.split_documents(docs)
print(result[0])
print(result[0].page_content)
# Out:
# page_content='Generative and Agentic AI in Software Development and the IT Domain
# Introduction' metadata={'source': '../data/insights.txt'}
# Generative and Agentic AI in Software Development and the IT Domain
# Introduction
