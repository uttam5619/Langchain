# %%
from langchain_openai import ChatOpenAI
from langchain_core import tools
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain.agents import create_agent
from dotenv import load_dotenv
import os
# Out:
# C:\Users\UTTAM\AppData\Local\Temp\ipykernel_34196\4051739418.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %%
load_dotenv()
api = os.getenv('OPENAI_KEY')

# %%
search_tool = DuckDuckGoSearchRun()
result = search_tool.invoke('top 5 places to visit in patna')

# %%
llm = ChatOpenAI(
    model = 'gpt-4.1-nano',
    api_key = api,
    temperature = 0
)

# %%
agent = create_agent(
    model =llm,
    tools =[search_tool]
)

# %%
messages =[]

query = HumanMessage(content ='top 5 places to visit in patna')
messages.append(query)

# %%
response = agent.invoke({'messages':messages})
print(result)
print(response)
print(response["messages"][-1])
# Out:
# Here is a list of best places to visit in Patna which one must visit and enjoy a great time away exploring the historical treasures. Discover the best places to visit in Patna, Bihar's vibrant capital. Explore historical monuments, religious sites, museums, parks, and family-friendly attractions with practical travel tips and FAQs. Things to Do in Patna, India: See Tripadvisor's 19,023 traveler reviews and photos of Patna tourist attractions. Find what to do today, this weekend, or in July. We have reviews of the best places to see in Patna. Visit top-rated & must-see attractions. Discover the best places to visit in Patna with top attractions, local experiences, and travel tips. Explore Patna and plan your perfect trip. One of the world's oldest cities still inhabited is Patna, the capital of Bihar. The city, which was once known as Pataliputra, is a wealth of natural beauty, history, spirituality, and culture. Here is a comprehensive guide of Places to visit in Patna's must-see tourist attractions if you're considering a trip there.
# {'messages': [HumanMessage(content='top 5 places to visit in patna', additional_kwargs={}, response_metadata={}, id='1408974a-a040-4b24-a5a4-9ba888c7fbdb'), AIMessage(content="Patna, the capital of Bihar, is a city rich in history and culture. Here are the top 5 places to visit in Patna:\n\n1. Mahavir Mandir: A famous Hindu temple dedicated to Lord Hanuman, known for its spiritual significance and beautiful architecture.\n2. Patna Sahib (Takht Sri Patna Sahib): One of the five Takhts in Sikhism, this gurudwara is a major pilgrimage site and is associated with Guru Gobind Singh.\n3. Golghar: A historic granary built by the British in 1786, offering panoramic views of the city from the top.\n4. Patna Museum: Home to a vast collection of artifacts, sculptures, and paintings that showcase Bihar's rich history and culture.\n5. Buddha Smriti Park: A serene park featuring a large Buddha statue, a meditation center, and a museum dedicated to Lord Buddha.\n\nWould you like more detailed information about any of these places?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 194, 'prompt_tokens': 82, 'total_tokens': 276, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_1f92ade527', 'id': 'chatcmpl-E6Rlm0oBfVSoWonq3noUIUpQMVuaM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fa688-efad-7a81-a1ca-aabb86e3a80a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 82, 'output_tokens': 194, 'total_tokens': 276, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# content="Patna, the capital of Bihar, is a city rich in history and culture. Here are the top 5 places to visit in Patna:\n\n1. Mahavir Mandir: A famous Hindu temple dedicated to Lord Hanuman, known for its spiritual significance and beautiful architecture.\n2. Patna Sahib (Takht Sri Patna Sahib): One of the five Takhts in Sikhism, this gurudwara is a major pilgrimage site and is associated with Guru Gobind Singh.\n3. Golghar: A historic granary built by the British in 1786, offering panoramic views of the city from the top.\n4. Patna Museum: Home to a vast collection of artifacts, sculptures, and paintings that showcase Bihar's rich history and culture.\n5. Buddha Smriti Park: A serene park featuring a large Buddha statue, a meditation center, and a museum dedicated to Lord Buddha.\n\nWould you like more detailed information about any of these places?" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 194, 'prompt_tokens': 82, 'total_tokens': 276, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_1f92ade527', 'id': 'chatcmpl-E6Rlm0oBfVSoWonq3noUIUpQMVuaM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019fa688-efad-7a81-a1ca-aabb86e3a80a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 82, 'output_tokens': 194, 'total_tokens': 276, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(response["messages"][-1].content)
# Out:
# Patna, the capital of Bihar, is a city rich in history and culture. Here are the top 5 places to visit in Patna:
#
# 1. Mahavir Mandir: A famous Hindu temple dedicated to Lord Hanuman, known for its spiritual significance and beautiful architecture.
# 2. Patna Sahib (Takht Sri Patna Sahib): One of the five Takhts in Sikhism, this gurudwara is a major pilgrimage site and is associated with Guru Gobind Singh.
# 3. Golghar: A historic granary built by the British in 1786, offering panoramic views of the city from the top.
# 4. Patna Museum: Home to a vast collection of artifacts, sculptures, and paintings that showcase Bihar's rich history and culture.
# 5. Buddha Smriti Park: A serene park featuring a large Buddha statue, a meditation center, and a museum dedicated to Lord Buddha.
#
# Would you like more detailed information about any of these places?
