# %%
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_community.tools import ShellTool
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api = os.getenv('OPENAI_API')

# %%
# this tool helps to run a cmd in shell
shell_tool= ShellTool()
result= shell_tool.invoke('whoami')
print(result)
# Out:
# Executing command:
#  whoami
# laptop-n5d26onq\uttam
# e:\ai_ml\generativeAI\langChain\tools\.venv\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
search_tool= DuckDuckGoSearchRun()
result= search_tool.invoke('ipl news')
print(result)
# Out:
# Get IPL 2026 live scores, ball-by-ball commentary, cricket schedule, ICC rankings and latest cricket news. IPL 2026: Get live IPL 2026 coverage with match schedules, points tables, fixtures, match results, and the latest IPL news. The official IPL website with live scores, match updates, team rankings, all the latest news, and videos . Live cricket scores, commentary, news, schedules, results, points tables, rankings, highlights, videos and player stats for international and domestic matches. Get the latest Cricket news, live match updates, ICC schedules, rankings, photos, videos, player stats, and full coverage of International, domestic, and T20 matches on news18.com.
